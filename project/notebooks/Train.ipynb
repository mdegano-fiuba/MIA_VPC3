# %%
# Clonar repositorio
# !git clone https://github.com/mdegano-fiuba/MIA_VPC3.git
# Out:
# Cloning into 'MIA_VPC3'...
# remote: Enumerating objects: 457, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 457 (delta 48), reused 111 (delta 42), pack-reused 334 (from 1)
# Receiving objects: 100% (457/457), 76.49 MiB | 16.75 MiB/s, done.
# Resolving deltas: 100% (136/136), done.

# %%
import sys
import os

# Cambiar al directorio raíz del proyecto
project_root = "/content/MIA_VPC3/project"
os.chdir(project_root)
print("Directorio de trabajo actual:", os.getcwd())

# Añadir la carpeta raíz al sys.path para que Python encuentre 'configs'
if project_root not in sys.path:
    sys.path.append(project_root)
# Out:
# Directorio de trabajo actual: /content/MIA_VPC3/project

# %%
# !pip install -r requirements.txt --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 108.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 106.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 753.9/753.9 kB 58.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 18.4 MB/s eta 0:00:00

# %%
from training.train import train

train()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00002.parquet:   0%|          | 0.00/330M [00:00<?, ?B/s]
# data/train-00001-of-00002.parquet:   0%|          | 0.00/391M [00:00<?, ?B/s]
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/200 [00:00<?, ? examples/s]
# preprocessor_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/22.5M [00:00<?, ?B/s]
# ...

# %%
# Descargar mlruns para persistirlo en GitHub y verlos en MLFlow UI
from google.colab import files
import shutil
from configs.config import CONFIG

# Comprimir la carpeta mlruns
shutil.make_archive("mlruns", 'zip', CONFIG['mlflow']['tracking_uri'])

# Descargar ZIP con todos los artefactos del modelo
files.download("mlruns.zip")

# Comprimir la carpeta del dataset para evaluación
shutil.make_archive("testDS", 'zip', CONFIG['folders']['test_dataset'])

# Descargar ZIP para persistir en GitHub
files.download("testDS.zip")
