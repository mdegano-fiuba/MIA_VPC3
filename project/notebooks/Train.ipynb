# %%
# Clonar repositorio
# !git clone https://github.com/mdegano-fiuba/MIA_VPC3.git
# Out:
# Cloning into 'MIA_VPC3'...
# remote: Enumerating objects: 594, done.
# remote: Counting objects: 100% (260/260), done.
# remote: Compressing objects: 100% (155/155), done.
# remote: Total 594 (delta 104), reused 238 (delta 87), pack-reused 334 (from 1)
# Receiving objects: 100% (594/594), 99.64 MiB | 23.58 MiB/s, done.
# Resolving deltas: 100% (192/192), done.

# %%
import sys
import os

# Cambiar al directorio raíz del proyecto
project_root = "/content/MIA_VPC3/project"
os.chdir(project_root)
print("Directorio de trabajo actual:", os.getcwd())

# Añadir la carpeta raíz al sys.path para que Python encuentre 'configs'
if project_root not in sys.path:
    sys.path.append(project_root)
# Out:
# Directorio de trabajo actual: /content/MIA_VPC3/project

# %%
# !pip install -r requirements.txt --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 97.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 75.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 84.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 753.9/753.9 kB 56.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 19.9 MB/s eta 0:00:00

# %%
from training.train import train

train()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00002.parquet:   0%|          | 0.00/330M [00:00<?, ?B/s]
# data/train-00001-of-00002.parquet:   0%|          | 0.00/391M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/23410 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/200 [00:00<?, ? examples/s]
# preprocessor_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/22.5M [00:00<?, ?B/s]
# Some weights of MobileViTForImageClassification were not initialized from the model checkpoint at apple/mobilevit-small and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([1000, 640]) in the checkpoint and torch.Size([2, 640]) in the model instantiated
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([2]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/800 [00:00<?, ? examples/s]
# model.safetensors:   0%|          | 0.00/22.4M [00:00<?, ?B/s]
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# /usr/local/lib/python3.12/dist-packages/mlflow/tracking/_tracking_service/utils.py:177: FutureWarning: The filesystem tracking backend (e.g., './mlruns') will be deprecated in February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://github.com/mlflow/mlflow/issues/18534 for more details and migration guidance.
#   return FileStore(store_uri, store_uri)
# 2025/12/06 23:35:55 INFO mlflow.tracking.fluent: Experiment with name 'cats_vs_dogs_experiment' does not exist. Creating a new experiment.
#     <div>
#
#       <progress value='500' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 03:29, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.580900</td>
#       <td>0.526801</td>
#       <td>0.970000</td>
#       <td>0.969697</td>
#       <td>0.979592</td>
#       <td>0.960000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.365700</td>
#       <td>0.331586</td>
#       <td>0.985000</td>
#       <td>0.984925</td>
#       <td>0.989899</td>
#       <td>0.980000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.247700</td>
#       <td>0.205925</td>
#       <td>0.990000</td>
#       <td>0.990000</td>
#       <td>0.990000</td>
#       <td>0.990000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.323000</td>
#       <td>0.137883</td>
#       <td>0.985000</td>
#       <td>0.985075</td>
#       <td>0.980198</td>
#       <td>0.990000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.190100</td>
#       <td>0.100889</td>
#       <td>0.990000</td>
#       <td>0.990000</td>
#       <td>0.990000</td>
#       <td>0.990000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.200600</td>
#       <td>0.091524</td>
#       <td>0.985000</td>
#       <td>0.985075</td>
#       <td>0.980198</td>
#       <td>0.990000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.109400</td>
#       <td>0.079612</td>
#       <td>0.990000</td>
#       <td>0.990099</td>
#       <td>0.980392</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.107100</td>
#       <td>0.078549</td>
#       <td>0.985000</td>
#       <td>0.985075</td>
#       <td>0.980198</td>
#       <td>0.990000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.059600</td>
#       <td>0.076706</td>
#       <td>0.985000</td>
#       <td>0.985075</td>
#       <td>0.980198</td>
#       <td>0.990000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.191000</td>
#       <td>0.077586</td>
#       <td>0.985000</td>
#       <td>0.985222</td>
#       <td>0.970874</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# Epoch 1 - Metrics so far: {'loss': 0.5809, 'grad_norm': 1.5513416528701782, 'learning_rate': 4.5100000000000005e-05, 'epoch': 1.0, 'step': 50}
# Epoch 2 - Metrics so far: {'loss': 0.3657, 'grad_norm': 1.4255861043930054, 'learning_rate': 4.0100000000000006e-05, 'epoch': 2.0, 'step': 100}
# Epoch 3 - Metrics so far: {'loss': 0.2477, 'grad_norm': 1.7464860677719116, 'learning_rate': 3.51e-05, 'epoch': 3.0, 'step': 150}
# Epoch 4 - Metrics so far: {'loss': 0.323, 'grad_norm': 1.2277264595031738, 'learning_rate': 3.01e-05, 'epoch': 4.0, 'step': 200}
# Epoch 5 - Metrics so far: {'loss': 0.1901, 'grad_norm': 2.049812078475952, 'learning_rate': 2.51e-05, 'epoch': 5.0, 'step': 250}
# Epoch 6 - Metrics so far: {'loss': 0.2006, 'grad_norm': 1.9356887340545654, 'learning_rate': 2.01e-05, 'epoch': 6.0, 'step': 300}
# Epoch 7 - Metrics so far: {'loss': 0.1094, 'grad_norm': 2.359320878982544, 'learning_rate': 1.51e-05, 'epoch': 7.0, 'step': 350}
# Epoch 8 - Metrics so far: {'loss': 0.1071, 'grad_norm': 1.1353144645690918, 'learning_rate': 1.0100000000000002e-05, 'epoch': 8.0, 'step': 400}
# Epoch 9 - Metrics so far: {'loss': 0.0596, 'grad_norm': 0.9527283310890198, 'learning_rate': 5.1e-06, 'epoch': 9.0, 'step': 450}
# Epoch 10 - Metrics so far: {'loss': 0.191, 'grad_norm': 5.203746795654297, 'learning_rate': 1.0000000000000001e-07, 'epoch': 10.0, 'step': 500}

# %%
# Descargar mlruns para persistirlo en GitHub y verlos en MLFlow UI
from google.colab import files
import shutil
from configs.config import CONFIG

# Comprimir la carpeta mlruns
shutil.make_archive("mlruns", 'zip', CONFIG['folders']['mlruns'])

# Descargar ZIP con todos los artefactos del modelo
files.download("mlruns.zip")

# Comprimir la carpeta del dataset para evaluación
shutil.make_archive("testDS", 'zip', CONFIG['folders']['test_dataset'])

# Descargar ZIP para persistir en GitHub
files.download("testDS.zip")
