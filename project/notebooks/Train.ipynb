# %%
# Clonar repositorio
# !git clone https://github.com/mdegano-fiuba/MIA_VPC3.git
# Out:
# Cloning into 'MIA_VPC3'...
# remote: Enumerating objects: 787, done.
# remote: Counting objects: 100% (154/154), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 787 (delta 49), reused 133 (delta 37), pack-reused 633 (from 1)
# Receiving objects: 100% (787/787), 146.27 MiB | 27.88 MiB/s, done.
# Resolving deltas: 100% (263/263), done.

# %%
import sys
import os

# Cambiar al directorio raíz del proyecto
project_root = "/content/MIA_VPC3/project"
os.chdir(project_root)
print("Directorio de trabajo actual:", os.getcwd())

# Añadir la carpeta raíz al sys.path para que Python encuentre 'configs'
if project_root not in sys.path:
    sys.path.append(project_root)
# Out:
# Directorio de trabajo actual: /content/MIA_VPC3/project

# %%
# !pip install -r requirements.txt --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 89.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 100.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 75.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 753.9/753.9 kB 52.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 19.5 MB/s eta 0:00:00

# %%
from training.train import train

train()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00002.parquet:   0%|          | 0.00/330M [00:00<?, ?B/s]
# data/train-00001-of-00002.parquet:   0%|          | 0.00/391M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/23410 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1000 [00:00<?, ? examples/s]
# preprocessor_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/22.5M [00:00<?, ?B/s]
# Some weights of MobileViTForImageClassification were not initialized from the model checkpoint at apple/mobilevit-small and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([1000, 640]) in the checkpoint and torch.Size([2, 640]) in the model instantiated
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([2]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/4000 [00:00<?, ? examples/s]
# model.safetensors:   0%|          | 0.00/22.4M [00:00<?, ?B/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# /usr/local/lib/python3.12/dist-packages/mlflow/tracking/_tracking_service/utils.py:177: FutureWarning: The filesystem tracking backend (e.g., './mlruns') will be deprecated in February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://github.com/mlflow/mlflow/issues/18534 for more details and migration guidance.
#   return FileStore(store_uri, store_uri)
# 2025/12/07 20:08:49 INFO mlflow.tracking.fluent: Experiment with name 'cats_vs_dogs_experiment' does not exist. Creating a new experiment.
#     <div>
#
#       <progress value='3750' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3750/5000 27:04 < 09:01, 2.31 it/s, Epoch 15/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.157700</td>
#       <td>0.093633</td>
#       <td>0.988000</td>
#       <td>0.987952</td>
#       <td>0.991935</td>
#       <td>0.984000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.236500</td>
#       <td>0.046884</td>
#       <td>0.989000</td>
#       <td>0.989033</td>
#       <td>0.986083</td>
#       <td>0.992000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.232000</td>
#       <td>0.033288</td>
#       <td>0.989000</td>
#       <td>0.988967</td>
#       <td>0.991952</td>
#       <td>0.986000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.051000</td>
#       <td>0.040848</td>
#       <td>0.986000</td>
#       <td>0.985887</td>
#       <td>0.993902</td>
#       <td>0.978000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.013700</td>
#       <td>0.033016</td>
#       <td>0.991000</td>
#       <td>0.990955</td>
#       <td>0.995960</td>
#       <td>0.986000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.002200</td>
#       <td>0.029256</td>
#       <td>0.991000</td>
#       <td>0.990991</td>
#       <td>0.991984</td>
#       <td>0.990000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.001300</td>
#       <td>0.032911</td>
#       <td>0.991000</td>
#       <td>0.990991</td>
#       <td>0.991984</td>
#       <td>0.990000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.005900</td>
#       <td>0.031588</td>
#       <td>0.989000</td>
#       <td>0.989011</td>
#       <td>0.988024</td>
#       <td>0.990000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.006700</td>
#       <td>0.034485</td>
#       <td>0.990000</td>
#       <td>0.989960</td>
#       <td>0.993952</td>
#       <td>0.986000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.011200</td>
#       <td>0.025860</td>
#       <td>0.991000</td>
#       <td>0.990991</td>
#       <td>0.991984</td>
#       <td>0.990000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.012700</td>
#       <td>0.034328</td>
#       <td>0.991000</td>
#       <td>0.990991</td>
#       <td>0.991984</td>
#       <td>0.990000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000500</td>
#       <td>0.041501</td>
#       <td>0.988000</td>
#       <td>0.988024</td>
#       <td>0.986056</td>
#       <td>0.990000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000500</td>
#       <td>0.032785</td>
#       <td>0.990000</td>
#       <td>0.990000</td>
#       <td>0.990000</td>
#       <td>0.990000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000800</td>
#       <td>0.054305</td>
#       <td>0.989000</td>
#       <td>0.988922</td>
#       <td>0.995943</td>
#       <td>0.982000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.001800</td>
#       <td>0.064856</td>
#       <td>0.989000</td>
#       <td>0.988922</td>
#       <td>0.995943</td>
#       <td>0.982000</td>
#     </tr>
#   </tbody>
# </table><p>
# Epoch 1 - Metrics so far: {'loss': 0.1577, 'grad_norm': 2.3971755504608154, 'learning_rate': 4.7510000000000004e-05, 'epoch': 1.0, 'step': 250}
# Epoch 2 - Metrics so far: {'loss': 0.2365, 'grad_norm': 8.661844253540039, 'learning_rate': 4.5010000000000004e-05, 'epoch': 2.0, 'step': 500}
# Epoch 3 - Metrics so far: {'loss': 0.232, 'grad_norm': 29.250919342041016, 'learning_rate': 4.251e-05, 'epoch': 3.0, 'step': 750}
# Epoch 4 - Metrics so far: {'loss': 0.051, 'grad_norm': 5.20906925201416, 'learning_rate': 4.0010000000000005e-05, 'epoch': 4.0, 'step': 1000}
# Epoch 5 - Metrics so far: {'loss': 0.0137, 'grad_norm': 5.025270462036133, 'learning_rate': 3.751e-05, 'epoch': 5.0, 'step': 1250}
# Epoch 6 - Metrics so far: {'loss': 0.0022, 'grad_norm': 0.046936482191085815, 'learning_rate': 3.5010000000000005e-05, 'epoch': 6.0, 'step': 1500}
# Epoch 7 - Metrics so far: {'loss': 0.0013, 'grad_norm': 0.021507926285266876, 'learning_rate': 3.251e-05, 'epoch': 7.0, 'step': 1750}
# Epoch 8 - Metrics so far: {'loss': 0.0059, 'grad_norm': 1.755413293838501, 'learning_rate': 3.001e-05, 'epoch': 8.0, 'step': 2000}
# Epoch 9 - Metrics so far: {'loss': 0.0067, 'grad_norm': 5.165678977966309, 'learning_rate': 2.7510000000000003e-05, 'epoch': 9.0, 'step': 2250}
# Epoch 10 - Metrics so far: {'loss': 0.0112, 'grad_norm': 1.1104822158813477, 'learning_rate': 2.501e-05, 'epoch': 10.0, 'step': 2500}
# Epoch 11 - Metrics so far: {'loss': 0.0127, 'grad_norm': 15.570735931396484, 'learning_rate': 2.251e-05, 'epoch': 11.0, 'step': 2750}
# Epoch 12 - Metrics so far: {'loss': 0.0005, 'grad_norm': 0.005604459438472986, 'learning_rate': 2.001e-05, 'epoch': 12.0, 'step': 3000}
# Epoch 13 - Metrics so far: {'loss': 0.0005, 'grad_norm': 0.005690644029527903, 'learning_rate': 1.751e-05, 'epoch': 13.0, 'step': 3250}
# Epoch 14 - Metrics so far: {'loss': 0.0008, 'grad_norm': 0.00877635832875967, 'learning_rate': 1.5010000000000002e-05, 'epoch': 14.0, 'step': 3500}
# Epoch 15 - Metrics so far: {'loss': 0.0018, 'grad_norm': 0.014861617237329483, 'learning_rate': 1.2509999999999999e-05, 'epoch': 15.0, 'step': 3750}

# %%
# Descargar mlruns para persistirlo en GitHub y verlos en MLFlow UI
from google.colab import files
import shutil
from configs.config import CONFIG

# Comprimir la carpeta mlruns
shutil.make_archive("mlruns", 'zip', CONFIG['folders']['mlruns'])

# Descargar ZIP con todos los artefactos del modelo
files.download("mlruns.zip")

# Comprimir la carpeta del dataset para evaluación
shutil.make_archive("testDS", 'zip', CONFIG['folders']['test_dataset'])

# Descargar ZIP para persistir en GitHub
files.download("testDS.zip")
